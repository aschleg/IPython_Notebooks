# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from __future__ import print_function
import numpy as np
import pandas as pd
from scipy import stats
import matplotlib.pyplot as plt
import statsmodels.api as sm
import statsmodels.formula.api as smf
import statsmodels.formula.api as ols

# %%
import nltk

# %%
data = pd.DataFrame.from_csv('C:/Users/Aaron/Google_Drive/Projects/Excel/Simply_Measured/sent_new.csv')

# %%
data.head()
# Out:
#          Name        Day Day_of_Week  Hour_of_Day Part_of_Day  Followers  \
# Username
# @3MNews    3M  10/1/2013     Tuesday            9     Morning      20721
# @3MNews    3M  10/1/2013     Tuesday           13   Afternoon     124326
# @3MNews    3M  10/1/2013     Tuesday           19     Evening      20721
# @3MNews    3M  10/2/2013   Wednesday           11   Afternoon      20721
# @3MNews    3M  10/3/2013    Thursday           12   Afternoon      82782
#
#           Friends  Clicks  Potential_Impressions  Retweets  Replies  \
# Username
# @3MNews       151       0                  20721         1        0
# @3MNews       906      41                 124326         5        0
# @3MNews       151       0                  20721         0        0
# @3MNews       151       0                      1         0        0
# @3MNews       604       0                  82782        15        5
#
#           Engagement  Favorites  Klout_Score
# Username
# ...

# %%
data_model = smf.ols("Engagement ~ Hour_of_Day + Day_of_Week", data=data).fit()

# %%
print(data_model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:             Engagement   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                     2.654
# Date:                Tue, 17 Jun 2014   Prob (F-statistic):            0.00963
# Time:                        22:54:40   Log-Likelihood:            -2.8240e+05
# No. Observations:               35868   AIC:                         5.648e+05
# Df Residuals:                   35860   BIC:                         5.649e+05
# Df Model:                           7
# ...
#                                coef    std err          t      P>|t|      [95.0% Conf. Int.]
# --------------------------------------------------------------------------------------------
# Intercept                   91.6498     11.280      8.125      0.000        69.540   113.760
# ...

# %%
fig, ax = plt.subplots(figsize=(5,10))
fig = sm.graphics.influence_plot(data_model, ax=ax, criterion="cooks")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-6b6cb23b85a2> in <module>()
#       1 fig, ax = plt.subplots(figsize=(5,5))
# ----> 2 fig = sm.graphics.influence_plot(data_model, ax=ax, criterion="cooks")
#
# C:\Users\Aaron\Anaconda\lib\site-packages\statsmodels\graphics\regressionplots.pyc in influence_plot(results, external, alpha, criterion, size, plot_alpha, ax, **kwargs)
#     747         psize = infl.cooks_distance[0]
#     748     elif criterion.lower().startswith('coo'):
# --> 749         psize = np.abs(infl.dffits[0])
#     750     else:
#     751         raise ValueError("Criterion %s not understood" % criterion)
#
# C:\Users\Aaron\Anaconda\lib\site-packages\statsmodels\tools\decorators.pyc in __get__(self, obj, type)
#      93         if _cachedval is None:
#      94             # Call the "fget" function
# ...
