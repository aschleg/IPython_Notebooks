# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from xlwings import Range, Chart, Workbook
wb = Workbook()

# %%
data = pd.read_csv('C:/Users/Aaron/Google_Drive/Projects/Resources/Datasets/social/crunchbase/companies.csv')

# %%
data = pd.DataFrame(data)

# %%
data.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# ...
# 54279    True
# 54280    True
# 54281    True
# 54282    True
# 54283    True
# 54284    True
# 54285    True
# 54286    True
# 54287    True
# 54288    True
# 54289    True
# 54290    True
# 54291    True
# 54292    True
# 54293    True
# Length: 54294, dtype: bool

# %%
data.drop_duplicates()
# Out:
#                            permalink                name  \
# 0     /organization/canal-do-credito    Canal do Credito
# 1              /organization/waywire            #waywire
# 2    /organization/tv-communications  &TV Communications
# 3      /organization/rock-your-paper   'Rock' Your Paper
# 4     /organization/in-touch-network   (In)Touch Network
# 5              /organization/n-plusn          +n (PlusN)
# 6         /organization/club-domains       .Club Domains
# 7         /organization/fox-networks       .Fox Networks
# 8              /organization/0-6-com             0-6.com
# 9               /organization/0xdata              0xdata
# 10         /organization/1-2-3-listo         1,2,3 Listo
# 11       /organization/1-800-dentist       1-800-DENTIST
# 12       /organization/1-800-doctors       1-800-DOCTORS
# 13         /organization/10-20-media         10-20 Media
# 14          /organization/1000-corks          1000 Corks
# ...

# %%
companies = pd.DataFrame(data, columns=['name', 'category_list', ' market ', 'country_code', 'state_code', 'region', 'funding_total_usd', 'founded_at', 'founded_year', 'first_funding_at'])

# %%
companies
# Out:
#                   name                                      category_list  \
# 0     Canal do Credito               |Credit|Technology|Services|Finance|
# 1             #waywire         |Entertainment|Politics|Social Media|News|
# 2   &TV Communications                                            |Games|
# 3    'Rock' Your Paper                             |Publishing|Education|
# 4    (In)Touch Network  |Electronics|Guides|Coffee|Restaurants|Music|i...
# 5           +n (PlusN)                                         |Software|
# 6        .Club Domains                                         |Software|
# 7        .Fox Networks                                      |Advertising|
# 8              0-6.com                                      |Curated Web|
# 9               0xdata                                        |Analytics|
# 10         1,2,3 Listo                                       |E-Commerce|
# 11       1-800-DENTIST                              |Health and Wellness|
# ...

# %%
companies = companies.rename(columns = {' market ': 'market'})

# %%
social = companies['funding_total_usd'].groupby(companies['market'].str.contains('social'))
